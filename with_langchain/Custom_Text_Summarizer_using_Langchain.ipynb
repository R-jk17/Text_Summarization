# %%
# !pip install langchain transformers PyPDF2 pypdf -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 80.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.0/276.0 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 26.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.document_loaders import PyPDFLoader
from langchain import PromptTemplate
from langchain.llms import HuggingFaceHub
import glob

# %%
llm = HuggingFaceHub(huggingfacehub_api_token='...',repo_id='google/flan-t5-base',
                     model_kwargs={"temperature":0.5,
                                   "max_length":512})

# %%
def summarize_pdf(pdf_file_path):
    loader = PyPDFLoader(pdf_file_path)
    docs = loader.load_and_split()
    chain = load_summarize_chain(llm, chain_type="map_reduce")
    summary = chain.run(docs)
    return summary

# %%
pdf_file_path = '/content/pdfs/CG-Unit 8.pdf'
summarize_pdf(pdf_file_path)
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# 'CSIT Unit 8 Illumination Models & Surface Rendering Techniques Phong model: Il,spec=KsIlcosns Combined diffuse and s pecular reflection I=Idiff+Ispec I=IaKa+IlKd( N .L)+ KsIl(V .R)ns Intensity Attenuation Intensity is attenuated by the factor 1/d2, where d is the distance that the light has traveled. This means that a surface close to the light source (small d) receives a higher incident intensity from the source than a distant surface (large d). Graphics package have a general inve rse quadratic attenuation function f(d)=min (1,1 a0+a1d+a2d2) User can fiddle with the coefficients a0, a1, a2 to obtain a variety of lig hting effects for a scene. With a given set of attenuation coefficients, we can then write our basic illumination model as I=KaIa+f(di)ILi[kd(N.Li)+ks(N.Hi)ns]n i=1 Where d is the distance l ight has traveled from light source i. L=incident light N=normal to surface R=direction of ideal specular r effraction V=viewer =angle betn R & V The color of the surface of a transparent object depends on the degree of transparency of the surface. A comprehensive list of methods for rendering polygon surfaces. Gouraud shading method - Developed by Henri Gouraud. Phong shading method - Developed by Phong Bui Tuong. 122 Computer Graphics (Reference Note) BSc. CSIT We can write this, Idiff(x,y)=ax+by+c (dx2+exy+fy2+gx+hy+i)1/2...........(i)1/2...(i) Where, a, b, c, d are used to represent the various dot product. For e.g'
